# %% [markdown]
# TMDb API enables you to find out the latest information about TV Shows, Movies and the biggest names in entertainment sector for a marvelous and fun TV/Movie watching experience.

# %%
api_key = '7ccfbd778ba44825eeda6c5ab6f4424b'
#example : https://api.themoviedb.org/3/movie/550?api_key=7ccfbd778ba44825eeda6c5ab6f4424b
api_read_acess_token  = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3Y2NmYmQ3NzhiYTQ0ODI1ZWVkYTZjNWFiNmY0NDI0YiIsInN1YiI6IjYzYjE5ZWE0YzU2ZDJkMDBhOTgyY2E4MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.fOakznsGsv_7cJZaiL81lnUZVudi1o1IXfldihDJJFM'

# %%
import json 
import requests 

r = requests.get('https://api.themoviedb.org/3/movie/76341?api_key=7ccfbd778ba44825eeda6c5ab6f4424b' )

# %%
r.text
# Out:
# '{"adult":false,"backdrop_path":"/nlCHUWjY9XWbuEUQauCBgnY8ymF.jpg","belongs_to_collection":{"id":8945,"name":"Mad Max Collection","poster_path":"/bmzns8d1tz3P2EWoz2JQeqnu9Ck.jpg","backdrop_path":"/gwYe803SFwKlCF5y71OicWHUnVD.jpg"},"budget":150000000,"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.warnerbros.com/movies/mad-max-fury-road","id":76341,"imdb_id":"tt1392190","original_language":"en","original_title":"Mad Max: Fury Road","overview":"An apocalyptic story set in the furthest reaches of our planet, in a stark desert landscape where humanity is broken, and most everyone is crazed fighting for the necessities of life. Within this world exist two rebels on the run who just might be able to restore order.","popularity":74.869,"poster_path":"/8tZYtuWezp8JbcsvHYO0O46tFbo.jpg","production_companies":[{"id":79,"logo_path":"/tpFpsqbleCzEE2p5EgvUq6ozfCA.png","name":"Village Roadshow Pictures","origin_country":
# ...

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/nlCHUWjY9XWbuEUQauCBgnY8ymF.jpg',
#  'belongs_to_collection': {'id': 8945,
#   'name': 'Mad Max Collection',
#   'poster_path': '/bmzns8d1tz3P2EWoz2JQeqnu9Ck.jpg',
#   'backdrop_path': '/gwYe803SFwKlCF5y71OicWHUnVD.jpg'},
#  'budget': 150000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'https://www.warnerbros.com/movies/mad-max-fury-road',
#  'id': 76341,
#  'imdb_id': 'tt1392190',
#  'original_language': 'en',
#  'original_title': 'Mad Max: Fury Road',
#  'overview': 'An apocalyptic story set in the furthest reaches of our planet, in a stark desert landscape where humanity is broken, and most everyone is crazed fighting for the necessities of life. Within this world exist two rebels on the run who just might be able to restore order.',
#  'popularity': 74.869,
#  'poster_path': '/8tZYtuWezp8JbcsvHYO0O46tFbo.jpg',
# ...

# %%
r.url
# Out:
# 'https://api.themoviedb.org/3/movie/76341?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
# find id on andhadun

# %%
answer1 = requests.get("https://api.themoviedb.org/3/movie/534780?api_key=7ccfbd778ba44825eeda6c5ab6f4424b")

# %%
answer1
# Out:
# <Response [200]>

# %%
film = answer1.json()

# %%
film
# Out:
# {'adult': False,
#  'backdrop_path': '/wJLV2ygHhTHG0nRTXlvA6wS8ubL.jpg',
#  'belongs_to_collection': None,
#  'budget': 4500000,
#  'genres': [{'id': 80, 'name': 'Crime'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 35, 'name': 'Comedy'}],
#  'homepage': '',
#  'id': 534780,
#  'imdb_id': 'tt8108198',
#  'original_language': 'hi',
#  'original_title': 'अंधाधुन',
#  'overview': 'A series of mysterious events changes the life of a blind pianist who now must report a crime that was actually never witnessed by him.',
#  'popularity': 9.547,
#  'poster_path': '/dy3K6hNvwE05siGgiLJcEiwgpdO.jpg',
#  'production_companies': [{'id': 6808,
#    'logo_path': '/xa1Yz7B5eRC2F9oHA6mDn8NE6ci.png',
#    'name': 'Viacom18 Studios',
#    'origin_country': 'IN'},
#   {'id': 115954,
#    'logo_path': '/xjXd4fVh3nAp3fi0cJgjfAQ1yBt.png',
#    'name': 'Matchbox Pictures',
#    'origin_country': 'IN'}],
#  'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#  'release_date': '2018-10-05',
# ...

# %%
answer1.url
# Out:
# 'https://api.themoviedb.org/3/movie/534780?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
film['title']
# Out:
# 'Andhadhun'

# %%
film['id']
# Out:
# 534780

# %%
#Fetch the company id company 'Marvel Studios' using TMDb. Print the id.

# %%
import requests
## Write your code here

import json
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b","query":"Marvel Studios"}
response = requests.get("https://api.themoviedb.org/3/search/company",params = info)

data = response.json()
print(data["results"][0]["id"])
# Out:
# 420

# %%
# 3-idots

# %%
import requests
## Write your code here

import json
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b","query":"3 Idiots"}
value = requests.get('https://api.themoviedb.org/3/search/movie' , params = info)

# %%
value
# Out:
# <Response [200]>

# %%
value.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/u7kuUaySqXBVAtqEl9vkTkAzHV9.jpg","genre_ids":[18,35],"id":20453,"original_language":"hi","original_title":"3 Idiots","overview":"Rascal. Joker. Dreamer. Genius... You\'ve never met a college student quite like \\"Rancho.\\" From the moment he arrives at India\'s most prestigious university, Rancho\'s outlandish schemes turn the campus upside down—along with the lives of his two newfound best friends. Together, they make life miserable for \\"Virus,\\" the school’s uptight and heartless dean. But when Rancho catches the eye of the dean\'s sexy daughter, Virus sets his sights on flunking out the \\"3 idiots\\" once and for all.","popularity":32.724,"poster_path":"/66A9MqXOyVFCssoloscw79z8Tew.jpg","release_date":"2009-12-23","title":"3 Idiots","video":false,"vote_average":8,"vote_count":1972},{"adult":false,"backdrop_path":"/16UEQo8TSAJoAMNdoEJm7lJIABf.jpg","genre_ids":[18,35],"id":452,"original_language":"da","original_title":"Idio
# ...

# %%
data = value.json()

# %%
for i in data['results']:
    if(i['title'] =='3 Idiots'):
        print(i['vote_count'] , i['vote_average'])
# Out:
# 1972 8

# %%
value.url
# Out:
# 'https://api.themoviedb.org/3/search/movie?api_key=7ccfbd778ba44825eeda6c5ab6f4424b&query=3+Idiots'

# %%
#similar to inception

# %%
import requests
import json 
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b","query":"Inception"}
value = requests.get('https://api.themoviedb.org/3/get/')
value.url
# Out:
# 'https://api.themoviedb.org/3/get/movie/%7B27205%7D/?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
import requests
import json
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b","query":"Inception"}
value = requests.get('https://api.themoviedb.org/3/movie/27205/similar' , params = info)

# %%
v= list()
ved = value.json()
for i in ved['results']:
    v.append(i['title'])

# %%
final = value.json()

# %%
final
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/yeIpgoZWzbNqkeSYPwhNZQ5xCRX.jpg',
#    'genre_ids': [28, 80, 878, 53],
#    'id': 754,
#    'original_language': 'en',
#    'original_title': 'Face/Off',
#    'overview': 'In order to foil a terrorist plot, an FBI agent undergoes facial transplant surgery and assumes the identity of a criminal mastermind, who murdered his only son. The plan turns sour when the criminal wakes up prematurely and seeks revenge.',
#    'popularity': 35.673,
#    'poster_path': '/69Xzn8UdPbVnmqSChKz2RTpoNfB.jpg',
#    'release_date': '1997-06-27',
#    'title': 'Face/Off',
#    'video': False,
#    'vote_average': 7.009,
#    'vote_count': 4484},
#   {'adult': False,
#    'backdrop_path': '/xORxfun2s1Gn43nPbYkMpQZZ9sK.jpg',
#    'genre_ids': [10402, 35, 10749],
#    'id': 759,
#    'original_language': 'en',
#    'original_title': 'Gentlemen Prefer Blondes',
# ...

# %%
value.url
# Out:
# 'https://api.themoviedb.org/3/movie/top_rated?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
v = v[:5]
for i in v:print(i)
# Out:
# Face/Off
# Gentlemen Prefer Blondes
# The Mad Adventures of Rabbi Jacob
# City of Angels
# Cruel Intentions

# %%
#top rated movies

# %%
import requests
import json
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b"}
value = requests.get('https://api.themoviedb.org/3/movie/top_rated' , params = info)

# %%
final = value.json()

# %%
x =list()
y = list()
count = 1
for i in final['results']:
    if count<=10:
        if(i['original_language']=='en'):
            count +=1
            print(i['original_title'],'-',end = " ")
            print(*i['genre_ids'])
            
            
    else:
        break
# Out:
# The Godfather - 18 80
# The Shawshank Redemption - 18 80
# The Godfather Part II - 18 80
# Schindler's List - 18 36 10752
# 12 Angry Men - 18
# The Green Mile - 14 18 80
# The Dark Knight - 18 28 80 53
# Pulp Fiction - 53 80
# Gabriel's Inferno - 10749
# Forrest Gump - 35 18 10749

# %%
# for a in x:
#     print(a ,'-',end = " ")
#     for b in y:
#         print(b)
#         break
# Out:
# The Godfather - [18, 80]
# The Shawshank Redemption - [18, 80]
# The Godfather Part II - [18, 80]
# Schindler's List - [18, 80]
# 12 Angry Men - [18, 80]
# The Green Mile - [18, 80]
# The Dark Knight - [18, 80]
# Pulp Fiction - [18, 80]
# Gabriel's Inferno - [18, 80]
# Forrest Gump - [18, 80]

# %%
# import requests
# import json
# info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b"}
# value = requests.get('https://api.themoviedb.org/3/movie/top_rated' , params = info)
# final = value.json()
# x =list()
# y = list()
# count = 1
# for i in final['results']:
#     if count<=10:
#         if(i['original_language']=='en'):
#             count +=1
#             print(i['original_title'],'-',end = " ")
#             print(*i['genre_ids'])
            
            
#     else:
#         break

import requests 

api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
header = {'Accept': 'application/json'} 
params = {'api_key':api_key, 'region':'US'} 
response = requests.get(api_link + "/movie/top_rated", headers = header, params = params) 

data = response.json() 
results = data.get('results') 

title_array = [] 
genre_id_array = [] 

for result in results: 
    if result.get('original_language') == 'en': 
        title_array.append(result.get('title')) 
        genre_id_array.append(result.get('genre_ids')) 
        
# To get the genre name corresponding to genre_id 
response2 = requests.get(api_link + "/genre/movie/list", headers = header, params = params) 
data2 = response2.json() 
genres = data2.get('genres') 
mapping = {} 

for genre in genres: 
    mapping[genre.get('id')] = genre.get('name') 

for i in range(10): 
    print(title_array[i], "-", end=" ") 
    for id in genre_id_array[i]: 
        print(mapping.get(id), end = ", ") 
    print()
# Out:
# The Godfather - Drama, Crime,
# The Shawshank Redemption - Drama, Crime,
# The Godfather Part II - Drama, Crime,
# Schindler's List - Drama, History, War,
# 12 Angry Men - Drama,
# The Green Mile - Fantasy, Drama, Crime,
# The Dark Knight - Drama, Action, Crime, Thriller,
# Pulp Fiction - Thriller, Crime,
# Gabriel's Inferno - Romance,
# Forrest Gump - Comedy, Drama, Romance,

# %% [markdown]
# #Fetch the top rated english movies in the US region using the TMDb API. From the result, print the first 10 movies which have original language as english. Also print their genres.

# %%
import requests
import json
info = {"api_key":"7ccfbd778ba44825eeda6c5ab6f4424b"}
value = requests.get('https://api.themoviedb.org/3/account/movie/top_rated?api_key=7ccfbd778ba44825eeda6c5ab6f4424b' )

r = requests.get('https://api.themoviedb.org/3/account/movie/top_rated?api_key=7ccfbd778ba44825eeda6c5ab6f4424b' )

# %%
value.url
# Out:
# 'https://api.themoviedb.org/3/account/movie/top_rated?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
r.url
# Out:
# 'https://api.themoviedb.org/3/account/movie/top_rated?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %% [markdown]
# Fetch the top rated english movies in the US region using the TMDb API. From the result, print the first 10 movies which have original language as english. Also print their genres.
# Note: Do not use the search/movies API for finding genres.
# Output Format:
# movie_name_1 - genre_1, genre_2 ....
# and so on..

# %%
#tmdb birth of most popular person

# %%
import requests 
import json 
e = requests.get('https://api.themoviedb.org/3/person/popular?api_key=7ccfbd778ba44825eeda6c5ab6f4424b')

# %%
e.url
# Out:
# 'https://api.themoviedb.org/3/person/popular?api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
d = e.json()
name = list()
val = list()
for i in d['results']:
    name.append(i['name'])
    val.append(i['popularity'])
print(name[0],val[0])
# Out:
# Aya Asahina 844.532

# %%
import requests 
import json 
e = requests.get('https://api.themoviedb.org/3/person/popular?api_key=7ccfbd778ba44825eeda6c5ab6f4424b')
d = e.json()
name = list()
birth= list()
id = list()
for i in d['results']:
    id.append(i['id'])
    name.append(i['name'])
    birth.append(i['origin_country'])
print(id[0])
print(name[0],'-',birth[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [16], line 11
#       9     id.append(i['id'])
#      10     name.append(i['name'])
# ---> 11     birth.append(i['origin_country'])
#      12 print(id[0])
#      13 print(name[0],'-',birth[0])
#
# KeyError: 'origin_country'

# %%
for i in d['results']:
    print(i['id'])
# Out:
# 2359226
# 974169
# 1186625
# 6614
# 3194176
# 1642789
# 224513
# 1215399
# 2729190
# 1499908
# 1907997
# 17521
# 6161
# 1310719
# 31
# 8784
# 1834433
# 6886
# 1972974
# 8691

# %%
import json 
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Inception", 'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/movie", headers = header, params=params)
data = response.json()
results = data.get('results')
for result in results:
    if result.get('title') == 'Inception':
        id = result.get('id')
        #print(id)
params2 = {'api_key':api_key}
response2 = requests.get(api_link + "/movie/" + str(id) + "/similar", headers = header, params=params2)
data2 = response2.json()
results2 = data2.get('results')
for result in results2[:5]:
    print(result.get("title"))
# Out:
# Inception
# 300: Rise of an Empire
# Sherlock Holmes: A Game of Shadows
# Snow White and the Huntsman
# 13 Assassins

# %%
import json 
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Inception", 'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/movie", headers = header, params=params)

# %%
response.url
# Out:
# 'https://api.themoviedb.org/3/search/movie?query=Inception&api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
import requests
## Write your code here
import requests
# Write your code here
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key}
header = {'Accept': 'application/json'}
import requests
response1=requests.get(api_link+"/person/popular",headers=header,params=params)
d=response1.json()
most_popular=d['results'][0].get('id')
response2 = requests.get(api_link + "/person/"+str(most_popular), headers = header, params=params)
data=response2.text
data=response2.json()
print(most_popular)
print(data['name'],"-",data['place_of_birth'])
# Out:
# 2359226
# Aya Asahina - Hyōgo Prefecture, Japan

# %% [markdown]
# TMDb 2.2
# Send Feedback
# Fetch the Instagram and Twitter handle of Indian Actress "Alia Bhatt" from the TMDb API.
# Output Format
# Print the Instagram and Twitter IDs space separated.
# instagram_id twitter_id

# %%
# import json
# import requests
# #searching id of alia bhatt
# info = {'api_key':"7ccfbd778ba44825eeda6c5ab6f4424b","query":"Tom Cruise"}
# header = {'Accept': 'application/json'}
# query  = requests.get('https://api.themoviedb.org/3/movie/search/person' , params = info , headers = header)



import json 
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Alia Bhatt", 'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/person", headers = header, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.url
# Out:
# 'https://api.themoviedb.org/3/search/person?query=Alia+Bhatt&api_key=7ccfbd778ba44825eeda6c5ab6f4424b'

# %%
value = response.json()

# %%
alia_id = str(value['results'][0]['id'])

# %%
alia_id
# Out:
# '1108120'

# %%
response2 = requests.get(api_link +'/person/'+alia_id,headers = header , params = params)

# %%
response2
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'gender': 1,
#    'id': 1108120,
#    'known_for': [{'adult': False,
#      'backdrop_path': '/d2plahqbICvNTAvhk2lM0HojJGG.jpg',
#      'genre_ids': [18, 10749],
#      'id': 413543,
#      'media_type': 'movie',
#      'original_language': 'hi',
#      'original_title': 'Dear Zindagi',
#      'overview': 'An unconventional thinker helps a budding cinematographer gain a new perspective on life.',
#      'poster_path': '/oUg0N2isgZ5rrxdXnsemcKolfKZ.jpg',
#      'release_date': '2016-11-23',
#      'title': 'Dear Zindagi',
#      'video': False,
#      'vote_average': 7.1,
#      'vote_count': 194},
#     {'adult': False,
#      'backdrop_path': '/d3l7kgFJyLTTQSrR4ysCk5yeVyW.jpg',
#      'genre_ids': [28, 18],
#      'id': 579974,
#      'media_type': 'movie',
#      'original_language': 'te',
#      'original_title': 'రౌద్రం రణం రుధిరం',
# ...

# %%
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/person/"+str(1108120)+"/external_ids", headers = header, params=params)
data=response2.json()
print(data['instagram_id'],'',data['twitter_id'])
# Out:
# aliaabhatt  Aliaa08

# %%
#tom criuze

# %%
import json 
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Tom Cruise", 'api_key':api_key}
header = {'Accept': 'application/json'}
response = requests.get(api_link + "/search/person", headers = header, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
final = response.json()

# %%
tom_id = final['results'][0]['id']

# %%
tom_id
# Out:
# 500

# %%
response2 = requests.get(api_link + "/person/"+str(500)+"/movie_credits", headers = header, params=params)
data=response2.json()

# %%
data
# Out:
# {'cast': [{'adult': False,
#    'backdrop_path': '/nH6hPhJq3EEv9CnBZgXU3IQnpJo.jpg',
#    'genre_ids': [12, 53, 878],
#    'id': 74,
#    'original_language': 'en',
#    'original_title': 'War of the Worlds',
#    'overview': 'Ray Ferrier is a divorced dockworker and less-than-perfect father. Soon after his ex-wife and her new husband drop off his teenage son and young daughter for a rare weekend visit, a strange and powerful lightning storm touches down.',
#    'popularity': 52.629,
#    'poster_path': '/6Biy7R9LfumYshur3YKhpj56MpB.jpg',
#    'release_date': '2005-06-28',
#    'title': 'War of the Worlds',
#    'video': False,
#    'vote_average': 6.483,
#    'vote_count': 7260,
#    'character': 'Ray Ferrier',
#    'credit_id': '52fe4213c3a36847f800226b',
#    'order': 0},
#   {'adult': False,
#    'backdrop_path': '/qq4H9JfBKQ5DarMLI6lhUQjn9D7.jpg',
#    'genre_ids': [28, 53, 878, 9648],
#    'id': 180,
#    'original_language': 'en',
#    'original_title': 'Minority Report',
# ...

# %%
for result in data['cast']:
    if result['title']=='Top Gun':
        print(result['character'],)
for result in data['cast']:
    if result['title']=='Mission: Impossible - Fallout':
        print(result['character'])
for result in data['cast']:
    if result['title']=='Minority Report':
        print(result['character'])
for result in data['cast']:
    if result['title']=='Edge of Tomorrow':
        print(result['character'])
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton
# Maj. William 'Bill' Cage

# %%
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'James McAvoy'}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/search/person", headers = header, params=params)
data=response2.json()
result2=data.get('results')
for result in result2:
    print(result.get('id'),result.get('name'))
# Out:
# 5530 James McAvoy
# 2147941 Helen McAvoy-James

# %%
    
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'Deadpool 2'}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/person/"+str(5530)+"/movie_credits", headers = header, params=params)
data=response2.json()
for result in data['cast']:
    if result['title']=='Deadpool 2':
        a=result['title']
        if a=='Deadpool 2':
            print('Yes')
        else:
            print('No')
# Out:
# Yes

# %%
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/person/"+str(5530)+"/movie_credits", headers = header, params=params)
data=response2.json()
for result in data['cast']:
    if result['title']=='Deadpool 2':
        a=result['character']
        print('No')
# Out:
# No

# %%
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'Friends'}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/search/tv", headers = header, params=params)
data=response2.json()
results=data.get('results')
for result in results:
    if result.get('name')=='Friends':
        print(result.get('overview'))
# Out:
# Six young people from New York City, on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each other to be the perfect antidote to the pressures of life.

# %%
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key,'query':'The Big Bang Theory'}
header = {'Accept': 'application/json'}
response2 = requests.get(api_link + "/tv/"+str(1418)+"/season/"+str(6)+"/episode/"+str(5), headers = header, params=params)
data=response2.json()
print(data['name'],"-",data['air_date'])
# Out:
# The Holographic Excitation - 2012-10-25

# %%
import json 
import requests
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b"
api_link = "https://api.themoviedb.org/3"
params = {'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link+ "/trending/tv/week", headers = header, params = params) 
data = response.json()
results = data.get("results")

# %%
ids=[] 
for result in results[:5]: 
    ids.append(result.get("id"))

# %%
for id in ids: 
    response2 = requests.get(api_link + "/tv/" + str(id) , headers = header, params = params) 
    data2 = response2.json() 
    if (data2.get("tagline")) != "": 
        print(data2.get("tagline")) 
    else: 
        print('Empty')
# Out:
# Empty
# Every story has a beginning.
# There are 7 billion ways to solve a crime.
# Empty
# Empty

# %%
import requests as rq
page_num = 1
api_key = '7ccfbd778ba44825eeda6c5ab6f4424b'
api_link = 'https://api.themoviedb.org/3'
header = {'Accept':'application/json'}
params = {'language':'en','api_key':api_key}
r = rq.get(api_link+'/tv/airing_today',headers = header,params = params)
data = r.json()
# print(data)
res = data['results']
page_num = data.get('total_pages')

# %%
for i in range(1,page_num + 1):
    params = {'language':"en",'api_key':api_key,'page':i}
    r = rq.get(api_link+'/tv/airing_today',headers = header,params = params)
    data = r.json()
    results = data.get('results')
    for r in results:
        if r['original_language'] == 'en':
            print(r['name'])
# Out:
# Cuomo
# Willow
# Coronation Street
# Bhagya Lakshmi
# PBS NewsHour
# Richard Osman's House of Games
# EastEnders
# Chicago Fire
# The Price Is Right
# Days of Our Lives
# Chicago P.D.
# General Hospital
# National Treasure: Edge of History
# Chicago Med
# The Late Show with Stephen Colbert
# LIVE with Kelly and Ryan
# Late Night with Seth Meyers
# Big Sky
# Star Wars: The Bad Batch
# The Repair Shop
# The Challenge
# Emmerdale
# All Elite Wrestling: Dynamite
# Tamron Hall
# House Hunters
# Doctors
# Match of the Day
# Stonehouse
# Wheel of Fortune
# Let's Make a Deal
# Jimmy Kimmel Live!
# See No Evil
# Abbott Elementary
# Hot Bench
# Tug of Words
# Married at First Sight
# The Circle
# Guy's Grocery Games
# Nakarehas Na Puso
# Dickinson's Real Deal
# The View
# WWE's The Bump
# Home Economics
# Pretty Hard Cases
# Dimension 20
# Moonshiners
# My 600-lb Life: Where Are They Now?
# The Lion Skin
# Madoff: The Monster of Wall Street
# Ambulance
# Property Brothers: Forever Home
# ...

# %%
import requests
## Write your code here
api_key = "7ccfbd778ba44825eeda6c5ab6f4424b" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':'Money Heist','api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + '/search/tv/', headers = header, params = params) 
data = response.json() 
result=data.get('results')
for i in result:
    if i.get('name')=='Money Heist':
        id=i.get('id')    
params1={'id':id,'api_key':api_key}
response1 = requests.get(api_link + '/tv/' + str(id) + '/credits', headers = header, params = params1) 
data1 = response1.json() 
cast=data1.get('cast')
count_male=0
count_female=0
for c in cast:
    if c.get('gender')==1:
        count_female+=1
    if c.get('gender')==2:
        count_male+=1
print(count_male,count_female)
# Out:
# 10 5

# %%
html
